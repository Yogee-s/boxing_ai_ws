# %% [markdown]
# ### Label timestamp on video for consistency

# %%
# !ffmpeg \
  -i /home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring.mp4 \
  -vf "drawtext=fontfile=/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf:\
text='%{pts\:hms}':x=10:y=10:fontsize=24:fontcolor=white:box=1:boxcolor=0x00000099"\
  -c:v libx264 -crf 18 -c:a copy \
  /home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring_with_pts.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm7 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm7 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm7 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso6iso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:08:01.06, start: 0.000000, bitrate: 1446 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1314 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x64b89bdafdc0] using SAR=1/1
# [libx264 @ 0x64b89bdafdc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x64b89bdafdc0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x64b89bdafdc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring_with_pts.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso6iso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# frame=14430 fps=113 q=-1.0 Lsize=  150152kB time=00:08:01.03 bitrate=2557.1kbits/s dup=1 drop=0 speed=3.77x
# video:142134kB audio:7516kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.335656%
# [libx264 @ 0x64b89bdafdc0] frame I:65    Avg QP:12.08  size: 41267
# [libx264 @ 0x64b89bdafdc0] frame P:4919  Avg QP:16.24  size: 17248
# [libx264 @ 0x64b89bdafdc0] frame B:9446  Avg QP:19.66  size:  6142
# [libx264 @ 0x64b89bdafdc0] consecutive B-frames:  4.6% 18.1% 18.8% 58.5%
# [libx264 @ 0x64b89bdafdc0] mb I  I16..4: 29.2% 56.0% 14.8%
# [libx264 @ 0x64b89bdafdc0] mb P  I16..4: 10.0% 22.6%  2.2%  P16..4: 19.5%  8.9%  3.9%  0.0%  0.0%    skip:32.8%
# [libx264 @ 0x64b89bdafdc0] mb B  I16..4:  3.4%  4.7%  0.2%  B16..8: 28.4%  5.2%  0.9%  direct: 3.9%  skip:53.4%  L0:47.1% L1:47.1% BI: 5.8%
# [libx264 @ 0x64b89bdafdc0] 8x8 transform intra:62.2% inter:75.1%
# [libx264 @ 0x64b89bdafdc0] coded y,uvDC,uvAC intra: 31.5% 48.0% 18.5% inter: 10.3% 16.3% 1.8%
# [libx264 @ 0x64b89bdafdc0] i16 v,h,dc,p: 43% 20% 13% 24%
# [libx264 @ 0x64b89bdafdc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 18% 24%  3%  4%  4%  4%  3%  3%
# [libx264 @ 0x64b89bdafdc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 22% 14%  3%  7%  5%  5%  3%  2%
# [libx264 @ 0x64b89bdafdc0] i8c dc,h,v,p: 47% 20% 20% 14%
# [libx264 @ 0x64b89bdafdc0] Weighted P-Frames: Y:8.4% UV:7.5%
# [libx264 @ 0x64b89bdafdc0] ref P L0: 66.8% 14.1% 13.7%  5.3%  0.1%
# [libx264 @ 0x64b89bdafdc0] ref B L0: 84.4% 14.0%  1.5%
# [libx264 @ 0x64b89bdafdc0] ref B L1: 95.2%  4.8%
# [libx264 @ 0x64b89bdafdc0] kb/s:2420.70

# %% [markdown]
# ### Split Video using timestamps

# %%
import os
import subprocess
import pandas as pd
from pathlib import Path
from shutil import which

def find_video(video_name, search_dir="."):
    """
    Recursively search for "video_name.mp4" (case‐insensitive) under search_dir.
    Returns the first full path found, or None if not found.
    """
    target = f"{video_name.lower()}.mp4"
    for root, _, files in os.walk(search_dir):
        for f in files:
            if f.lower() == target:
                return os.path.join(root, f)
    return None

def ensure_ffmpeg_exists():
    """Raise an error if ffmpeg/ffprobe are not on PATH."""
    if which("ffmpeg") is None:
        raise RuntimeError("ffmpeg not found. Please install ffmpeg.")
    if which("ffprobe") is None:
        raise RuntimeError("ffprobe not found. Please install ffmpeg (includes ffprobe).")

def timestamp_to_seconds(ts_str):
    """Convert HH:MM:SS to total seconds."""
    h, m, s = map(int, ts_str.split(":"))
    return h*3600 + m*60 + s

def validate_timestamp(ts_str):
    """
    Normalize timestamp:
      - "MM:SS"        -> "00:MM:SS"
      - "HH:MM:00"     -> "00:HH:MM"
      - "HH:MM:SS"     -> unchanged
    """
    ts_str = ts_str.strip()
    parts = ts_str.split(":")
    # MM:SS (2 parts)
    if len(parts) == 2:
        mm, ss = map(int, parts)
        if 0 <= mm < 60 and 0 <= ss < 60:
            return f"00:{mm:02d}:{ss:02d}"
    # HH:MM:SS (3 parts)
    if len(parts) == 3:
        hh, mm, ss = map(int, parts)
        # if ends in :00, assume it was really MM:SS stored as HH:MM:00
        if ss == 0:
            return f"00:{hh:02d}:{mm:02d}"
        # otherwise valid HH:MM:SS
        if hh >= 0 and 0 <= mm < 60 and 0 <= ss < 60:
            return f"{hh:02d}:{mm:02d}:{ss:02d}"
    raise ValueError(f"Invalid timestamp format: '{ts_str}'")

def ffmpeg_cut_segment(input_path, start_ts, end_ts, output_path):
    """
    Reliable cut: seek before input, fixed duration, always re-encode
    with a keyframe at start and proper header.
    """
    start_sec = timestamp_to_seconds(start_ts)
    end_sec   = timestamp_to_seconds(end_ts)
    duration  = end_sec - start_sec
    if duration <= 0:
        raise RuntimeError(f"Invalid segment length: {start_ts} → {end_ts}")

    cmd = [
        "ffmpeg",
        "-hide_banner",
        "-loglevel", "info",
        "-ss",            start_ts,        # seek before input
        "-i",             input_path,
        "-t",             str(duration),   # duration in seconds
        "-c:v",           "libx264",       # re-encode video
        "-preset",        "fast",
        "-crf",           "23",
        "-c:a",           "aac",           # re-encode audio
        "-movflags",      "+faststart",    # header at front
        "-pix_fmt",       "yuv420p",
        "-y",
        output_path
    ]

    print(f"→ Cutting '{input_path}' from {start_ts} for {duration}s → '{output_path}'")
    result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if result.returncode != 0:
        print(result.stderr)
        raise RuntimeError(f"ffmpeg failed with code {result.returncode}")

    size = os.path.getsize(output_path)
    if size < 2000:
        raise RuntimeError(f"Output file too small ({size} bytes)")
    print(f"✔ Created: {output_path} ({size:,} bytes)")

def split_videos_from_sheet(sheet_path, search_dir, output_dir):
    ensure_ffmpeg_exists()

    # read spreadsheet, forcing Start/End as strings
    converters = {
        "Start": lambda x: str(x).strip(),
        "End":   lambda x: str(x).strip()
    }
    if sheet_path.lower().endswith(".csv"):
        df = pd.read_csv(sheet_path, converters=converters)
    else:
        df = pd.read_excel(sheet_path, converters=converters)
    df.columns = df.columns.str.strip()

    required = {"Video Name", "Start", "End", "Label"}
    if not required.issubset(df.columns):
        raise ValueError(f"Missing columns: found {df.columns.tolist()}")

    os.makedirs(output_dir, exist_ok=True)
    success = 0

    for idx, row in df.iterrows():
        try:
            name = str(row["Video Name"]).strip()
            if not name or name.lower() in ("nan", "none"):
                continue
            raw_start = row["Start"]
            raw_end   = row["End"]
            label     = str(row["Label"]).strip().lower().replace(" ", "_")

            print(f"\n[DEBUG] Row {idx+1}: Raw Start='{raw_start}', End='{raw_end}'")
            start_ts = validate_timestamp(raw_start)
            end_ts   = validate_timestamp(raw_end)
            print(f"[DEBUG] Row {idx+1}: Normalized {start_ts} → {end_ts}")

            video_path = find_video(name, search_dir)
            if video_path is None:
                print(f"[!] Video not found for '{name}' (skipping)")
                continue

            label_dir = os.path.join(output_dir, label)
            os.makedirs(label_dir, exist_ok=True)
            out_file = os.path.join(label_dir, f"{name}_{idx+1:03}.mp4")

            ffmpeg_cut_segment(video_path, start_ts, end_ts, out_file)
            success += 1

        except Exception as e:
            print(f"[X] Row {idx+1} failed: {e}")

    total = len(df)
    print(f"\nDone: {success}/{total} segments created.")

if __name__ == "__main__":
    split_videos_from_sheet(
        sheet_path="time_stamps/Boxing_Videos_Timestamp.xlsx",
        search_dir=".",
        output_dir="dataset"
    )
# Out:
# [DEBUG] Row 1: Raw Start='00:25:00', End='00:29:00'
# [DEBUG] Row 1: Normalized 00:00:25 → 00:00:29
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:00:25 for 4s → 'dataset/jab/slow_motion_sparring_001.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_001.mp4 (813,180 bytes)
#
# [DEBUG] Row 2: Raw Start='00:30:00', End='00:32:00'
# [DEBUG] Row 2: Normalized 00:00:30 → 00:00:32
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:00:30 for 2s → 'dataset/right_hook/slow_motion_sparring_002.mp4'
# ✔ Created: dataset/right_hook/slow_motion_sparring_002.mp4 (384,086 bytes)
#
# [DEBUG] Row 3: Raw Start='01:55:00', End='01:57:00'
# [DEBUG] Row 3: Normalized 00:01:55 → 00:01:57
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:01:55 for 2s → 'dataset/jab/slow_motion_sparring_003.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_003.mp4 (456,665 bytes)
#
# [DEBUG] Row 4: Raw Start='01:58:00', End='02:00:00'
# [DEBUG] Row 4: Normalized 00:01:58 → 00:02:00
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:01:58 for 2s → 'dataset/jab/slow_motion_sparring_004.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_004.mp4 (484,031 bytes)
#
# [DEBUG] Row 5: Raw Start='02:00:00', End='02:02:00'
# [DEBUG] Row 5: Normalized 00:02:00 → 00:02:02
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:00 for 2s → 'dataset/idle/slow_motion_sparring_005.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_005.mp4 (464,971 bytes)
#
# [DEBUG] Row 6: Raw Start='02:03:00', End='02:04:00'
# [DEBUG] Row 6: Normalized 00:02:03 → 00:02:04
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:03 for 1s → 'dataset/idle/slow_motion_sparring_006.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_006.mp4 (270,050 bytes)
#
# [DEBUG] Row 7: Raw Start='02:05:00', End='02:08:00'
# [DEBUG] Row 7: Normalized 00:02:05 → 00:02:08
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:05 for 3s → 'dataset/jab/slow_motion_sparring_007.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_007.mp4 (579,510 bytes)
#
# [DEBUG] Row 8: Raw Start='02:08:00', End='02:11:00'
# [DEBUG] Row 8: Normalized 00:02:08 → 00:02:11
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:08 for 3s → 'dataset/cross/slow_motion_sparring_008.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_008.mp4 (665,310 bytes)
#
# [DEBUG] Row 9: Raw Start='02:11:00', End='02:14:00'
# [DEBUG] Row 9: Normalized 00:02:11 → 00:02:14
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:11 for 3s → 'dataset/idle/slow_motion_sparring_009.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_009.mp4 (784,717 bytes)
#
# [DEBUG] Row 10: Raw Start='02:14:00', End='02:16:00'
# [DEBUG] Row 10: Normalized 00:02:14 → 00:02:16
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:14 for 2s → 'dataset/block/slow_motion_sparring_010.mp4'
# ✔ Created: dataset/block/slow_motion_sparring_010.mp4 (330,636 bytes)
#
# [DEBUG] Row 11: Raw Start='02:17:00', End='02:19:00'
# [DEBUG] Row 11: Normalized 00:02:17 → 00:02:19
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:17 for 2s → 'dataset/jab/slow_motion_sparring_011.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_011.mp4 (405,857 bytes)
#
# [DEBUG] Row 12: Raw Start='02:19:00', End='02:20:00'
# [DEBUG] Row 12: Normalized 00:02:19 → 00:02:20
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:19 for 1s → 'dataset/cross/slow_motion_sparring_012.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_012.mp4 (229,037 bytes)
#
# [DEBUG] Row 13: Raw Start='02:22:00', End='02:24:00'
# [DEBUG] Row 13: Normalized 00:02:22 → 00:02:24
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:22 for 2s → 'dataset/jab/slow_motion_sparring_013.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_013.mp4 (462,369 bytes)
#
# [DEBUG] Row 14: Raw Start='02:24:00', End='02:27:00'
# [DEBUG] Row 14: Normalized 00:02:24 → 00:02:27
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:24 for 3s → 'dataset/jab/slow_motion_sparring_014.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_014.mp4 (658,831 bytes)
#
# [DEBUG] Row 15: Raw Start='02:27:00', End='02:30:00'
# [DEBUG] Row 15: Normalized 00:02:27 → 00:02:30
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:27 for 3s → 'dataset/idle/slow_motion_sparring_015.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_015.mp4 (709,742 bytes)
#
# [DEBUG] Row 16: Raw Start='02:33:00', End='02:37:00'
# [DEBUG] Row 16: Normalized 00:02:33 → 00:02:37
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:33 for 4s → 'dataset/cross/slow_motion_sparring_016.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_016.mp4 (763,043 bytes)
#
# [DEBUG] Row 17: Raw Start='02:38:00', End='02:41:00'
# [DEBUG] Row 17: Normalized 00:02:38 → 00:02:41
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:38 for 3s → 'dataset/left_uppercut/slow_motion_sparring_017.mp4'
# ✔ Created: dataset/left_uppercut/slow_motion_sparring_017.mp4 (794,289 bytes)
#
# [DEBUG] Row 18: Raw Start='02:41:00', End='02:43:00'
# [DEBUG] Row 18: Normalized 00:02:41 → 00:02:43
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:41 for 2s → 'dataset/idle/slow_motion_sparring_018.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_018.mp4 (452,982 bytes)
#
# [DEBUG] Row 19: Raw Start='02:44:00', End='02:46:00'
# [DEBUG] Row 19: Normalized 00:02:44 → 00:02:46
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:44 for 2s → 'dataset/jab/slow_motion_sparring_019.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_019.mp4 (313,707 bytes)
#
# [DEBUG] Row 20: Raw Start='02:46:00', End='02:49:00'
# [DEBUG] Row 20: Normalized 00:02:46 → 00:02:49
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:46 for 3s → 'dataset/right_hook/slow_motion_sparring_020.mp4'
# ✔ Created: dataset/right_hook/slow_motion_sparring_020.mp4 (647,939 bytes)
#
# [DEBUG] Row 21: Raw Start='02:49:00', End='02:52:00'
# [DEBUG] Row 21: Normalized 00:02:49 → 00:02:52
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:49 for 3s → 'dataset/left_hook/slow_motion_sparring_021.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_021.mp4 (872,906 bytes)
#
# [DEBUG] Row 22: Raw Start='02:55:00', End='02:58:00'
# [DEBUG] Row 22: Normalized 00:02:55 → 00:02:58
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:55 for 3s → 'dataset/idle/slow_motion_sparring_022.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_022.mp4 (649,727 bytes)
#
# [DEBUG] Row 23: Raw Start='02:59:00', End='03:01:00'
# [DEBUG] Row 23: Normalized 00:02:59 → 00:03:01
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:59 for 2s → 'dataset/jab/slow_motion_sparring_023.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_023.mp4 (330,110 bytes)
#
# [DEBUG] Row 24: Raw Start='03:01:00', End='03:04:00'
# [DEBUG] Row 24: Normalized 00:03:01 → 00:03:04
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:01 for 3s → 'dataset/jab/slow_motion_sparring_024.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_024.mp4 (703,168 bytes)
#
# [DEBUG] Row 25: Raw Start='03:05:00', End='03:07:00'
# [DEBUG] Row 25: Normalized 00:03:05 → 00:03:07
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:05 for 2s → 'dataset/cross/slow_motion_sparring_025.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_025.mp4 (457,237 bytes)
#
# [DEBUG] Row 26: Raw Start='03:07:00', End='03:10:00'
# [DEBUG] Row 26: Normalized 00:03:07 → 00:03:10
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:07 for 3s → 'dataset/left_hook/slow_motion_sparring_026.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_026.mp4 (823,408 bytes)
#
# [DEBUG] Row 27: Raw Start='03:12:00', End='03:16:00'
# [DEBUG] Row 27: Normalized 00:03:12 → 00:03:16
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:12 for 4s → 'dataset/idle/slow_motion_sparring_027.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_027.mp4 (847,582 bytes)
#
# [DEBUG] Row 28: Raw Start='03:16:00', End='03:19:00'
# [DEBUG] Row 28: Normalized 00:03:16 → 00:03:19
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:16 for 3s → 'dataset/cross/slow_motion_sparring_028.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_028.mp4 (543,885 bytes)
#
# [DEBUG] Row 29: Raw Start='03:19:00', End='03:22:00'
# [DEBUG] Row 29: Normalized 00:03:19 → 00:03:22
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:19 for 3s → 'dataset/left_hook/slow_motion_sparring_029.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_029.mp4 (724,550 bytes)
#
# [DEBUG] Row 30: Raw Start='03:22:00', End='03:27:00'
# [DEBUG] Row 30: Normalized 00:03:22 → 00:03:27
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:22 for 5s → 'dataset/idle/slow_motion_sparring_030.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_030.mp4 (1,265,296 bytes)
#
# [DEBUG] Row 31: Raw Start='03:26:00', End='03:29:00'
# [DEBUG] Row 31: Normalized 00:03:26 → 00:03:29
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:26 for 3s → 'dataset/jab/slow_motion_sparring_031.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_031.mp4 (598,230 bytes)
#
# [DEBUG] Row 32: Raw Start='03:30:00', End='03:32:00'
# [DEBUG] Row 32: Normalized 00:03:30 → 00:03:32
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:30 for 2s → 'dataset/right_uppercut/slow_motion_sparring_032.mp4'
# ✔ Created: dataset/right_uppercut/slow_motion_sparring_032.mp4 (483,535 bytes)
#
# [DEBUG] Row 33: Raw Start='03:33:00', End='03:36:00'
# [DEBUG] Row 33: Normalized 00:03:33 → 00:03:36
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:33 for 3s → 'dataset/left_hook/slow_motion_sparring_033.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_033.mp4 (702,317 bytes)
#
# [DEBUG] Row 34: Raw Start='03:37:00', End='03:43:00'
# [DEBUG] Row 34: Normalized 00:03:37 → 00:03:43
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:37 for 6s → 'dataset/idle/slow_motion_sparring_034.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_034.mp4 (990,633 bytes)
#
# Done: 34/34 segments created.

# %% [markdown]
# ### Dataset with poses

# %%
import os
import cv2
import imageio
import numpy as np
import pandas as pd
from ultralytics import YOLO

# ─────────────────────────────────────────────────────────────────────────────
# CONFIGURATION (edit only these three lines)
# ─────────────────────────────────────────────────────────────────────────────

POSE_MODEL_PATH = "models/yolo11n-pose.pt"   # path to your YOLOv11-pose .pt
DATASET_ROOT    = "dataset"                  # folder containing subfolders “<label>/*.mp4”
OUTPUT_ROOT     = "dataset_with_poses"       # where to save .npy and labels.csv

# ─────────────────────────────────────────────────────────────────────────────
# SCRIPT BEGINS HERE – no other edits needed
# ─────────────────────────────────────────────────────────────────────────────

def find_all_clips(root_dir):
    """
    Yield (label, full_video_path, clip_name) for every .mp4 under root_dir/<label>/.
    """
    for label in os.listdir(root_dir):
        label_dir = os.path.join(root_dir, label)
        if not os.path.isdir(label_dir):
            continue
        for fname in os.listdir(label_dir):
            if fname.lower().endswith(".mp4"):
                clip_name = os.path.splitext(fname)[0]
                yield label, os.path.join(label_dir, fname), clip_name

def read_frames(path):
    """
    Try to read frames via imageio. If that fails, fallback to OpenCV.
    Return list of RGB frames (numpy arrays). Raise if both fail.
    """
    # First attempt: imageio + ffmpeg
    try:
        reader = imageio.get_reader(path, "ffmpeg")
        frames = [frame for frame in reader]
        reader.close()
        if frames:
            return frames
        # if no frames, treat as failure
    except Exception:
        pass

    # Fallback: OpenCV VideoCapture
    cap = cv2.VideoCapture(path)
    if not cap.isOpened():
        raise RuntimeError("Cannot open video with imageio or OpenCV")
    frames = []
    while True:
        ret, frame_bgr = cap.read()
        if not ret:
            break
        frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
        frames.append(frame_rgb)
    cap.release()
    if not frames:
        raise RuntimeError("Video opened but no frames read")
    return frames

def extract_pose_sequence(model, video_path):
    """
    Read every frame of video_path (RGB), run YOLOv11-pose on it,
    and return an array of shape (num_frames, num_keypoints*2).
    Zero‐fill if no person detected in a frame.
    """
    frames = read_frames(video_path)
    num_kpts = model.model.yaml["data"]["nc"]
    kp_list = []

    for frame in frames:
        results = model(frame)
        if len(results) > 0 and results[0].keypoints is not None:
            kps = results[0].keypoints.cpu().numpy()
            if kps.size > 0:
                arr = kps[0, :, :2].flatten()  # first person, x/y only
            else:
                arr = np.zeros(num_kpts * 2, dtype=float)
        else:
            arr = np.zeros(num_kpts * 2, dtype=float)
        kp_list.append(arr)

    return np.stack(kp_list, axis=0) if kp_list else None

def main():
    os.makedirs(OUTPUT_ROOT, exist_ok=True)
    model = YOLO(POSE_MODEL_PATH)
    rows = []

    for label, video_path, clip_name in find_all_clips(DATASET_ROOT):
        print(f"Processing {label}/{clip_name}.mp4 …")
        try:
            seq = extract_pose_sequence(model, video_path)
        except Exception as e:
            print(f"  ↳ skip (cannot read): {e}")
            continue

        if seq is None:
            print("  ↳ no frames: skipping")
            continue

        out_dir = os.path.join(OUTPUT_ROOT, label)
        os.makedirs(out_dir, exist_ok=True)
        npy_path = os.path.join(out_dir, f"{clip_name}.npy")
        np.save(npy_path, seq)

        rows.append({"npy_path": npy_path, "label": label})
        print(f"  ↳ saved {clip_name}.npy  (shape = {seq.shape})")

    df = pd.DataFrame(rows)
    df.to_csv(os.path.join(OUTPUT_ROOT, "labels.csv"), index=False)
    print("Done. labels.csv written to", OUTPUT_ROOT)

if __name__ == "__main__":
    main()
# Out:
# Processing block/slow_motion_sparring_009.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing right_hook/slow_motion_sparring_019.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing right_hook/slow_motion_sparring_001.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_030.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_003.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_000.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_018.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_012.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_006.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_023.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_002.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_010.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_022.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing jab/slow_motion_sparring_013.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing left_hook/slow_motion_sparring_025.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing left_hook/slow_motion_sparring_032.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing left_hook/slow_motion_sparring_028.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing left_hook/slow_motion_sparring_020.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing left_uppercut/slow_motion_sparring_016.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing right_uppercut/slow_motion_sparring_031.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_021.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_005.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_004.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_033.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_014.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_029.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_008.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_017.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing idle/slow_motion_sparring_026.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing cross/slow_motion_sparring_011.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing cross/slow_motion_sparring_024.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing cross/slow_motion_sparring_007.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing cross/slow_motion_sparring_027.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Processing cross/slow_motion_sparring_015.mp4 …
#   ↳ skip (cannot read): Cannot open video with imageio or OpenCV
# Done. labels.csv written to dataset_with_poses
