# %% [markdown]
# ### Label timestamp on video for easier labelling

# %%
# !ffmpeg \
  -i /home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring.mp4 \
  -vf "drawtext=fontfile=/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf:\
text='%{pts\:hms}':x=10:y=10:fontsize=24:fontcolor=white:box=1:boxcolor=0x00000099"\
  -c:v libx264 -crf 18 -c:a copy \
  /home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring_with_pts.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm7 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm7 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm7 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso6iso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:08:01.06, start: 0.000000, bitrate: 1446 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1314 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x64b89bdafdc0] using SAR=1/1
# [libx264 @ 0x64b89bdafdc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x64b89bdafdc0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x64b89bdafdc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/yogee/Desktop/boxing_move_predictor/data_raw/sparring_pov/slow_motion_sparring_with_pts.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso6iso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# frame=14430 fps=113 q=-1.0 Lsize=  150152kB time=00:08:01.03 bitrate=2557.1kbits/s dup=1 drop=0 speed=3.77x
# video:142134kB audio:7516kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.335656%
# [libx264 @ 0x64b89bdafdc0] frame I:65    Avg QP:12.08  size: 41267
# [libx264 @ 0x64b89bdafdc0] frame P:4919  Avg QP:16.24  size: 17248
# [libx264 @ 0x64b89bdafdc0] frame B:9446  Avg QP:19.66  size:  6142
# [libx264 @ 0x64b89bdafdc0] consecutive B-frames:  4.6% 18.1% 18.8% 58.5%
# [libx264 @ 0x64b89bdafdc0] mb I  I16..4: 29.2% 56.0% 14.8%
# [libx264 @ 0x64b89bdafdc0] mb P  I16..4: 10.0% 22.6%  2.2%  P16..4: 19.5%  8.9%  3.9%  0.0%  0.0%    skip:32.8%
# [libx264 @ 0x64b89bdafdc0] mb B  I16..4:  3.4%  4.7%  0.2%  B16..8: 28.4%  5.2%  0.9%  direct: 3.9%  skip:53.4%  L0:47.1% L1:47.1% BI: 5.8%
# [libx264 @ 0x64b89bdafdc0] 8x8 transform intra:62.2% inter:75.1%
# [libx264 @ 0x64b89bdafdc0] coded y,uvDC,uvAC intra: 31.5% 48.0% 18.5% inter: 10.3% 16.3% 1.8%
# [libx264 @ 0x64b89bdafdc0] i16 v,h,dc,p: 43% 20% 13% 24%
# [libx264 @ 0x64b89bdafdc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 18% 24%  3%  4%  4%  4%  3%  3%
# [libx264 @ 0x64b89bdafdc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 22% 14%  3%  7%  5%  5%  3%  2%
# [libx264 @ 0x64b89bdafdc0] i8c dc,h,v,p: 47% 20% 20% 14%
# [libx264 @ 0x64b89bdafdc0] Weighted P-Frames: Y:8.4% UV:7.5%
# [libx264 @ 0x64b89bdafdc0] ref P L0: 66.8% 14.1% 13.7%  5.3%  0.1%
# [libx264 @ 0x64b89bdafdc0] ref B L0: 84.4% 14.0%  1.5%
# [libx264 @ 0x64b89bdafdc0] ref B L1: 95.2%  4.8%
# [libx264 @ 0x64b89bdafdc0] kb/s:2420.70

# %% [markdown]
# ### Split Video using timestamps

# %%
import os
import subprocess
import pandas as pd
from pathlib import Path
from shutil import which

def find_video(video_name, search_dir="."):
    """
    Recursively search for "video_name.mp4" (case‐insensitive) under search_dir.
    Returns the first full path found, or None if not found.
    """
    target = f"{video_name.lower()}.mp4"
    for root, _, files in os.walk(search_dir):
        for f in files:
            if f.lower() == target:
                return os.path.join(root, f)
    return None

def ensure_ffmpeg_exists():
    """Raise an error if ffmpeg/ffprobe are not on PATH."""
    if which("ffmpeg") is None:
        raise RuntimeError("ffmpeg not found. Please install ffmpeg.")
    if which("ffprobe") is None:
        raise RuntimeError("ffprobe not found. Please install ffmpeg (includes ffprobe).")

def timestamp_to_seconds(ts_str):
    """Convert HH:MM:SS to total seconds."""
    h, m, s = map(int, ts_str.split(":"))
    return h*3600 + m*60 + s

def validate_timestamp(ts_str):
    """
    Normalize timestamp:
      - "MM:SS"        -> "00:MM:SS"
      - "HH:MM:00"     -> "00:HH:MM"
      - "HH:MM:SS"     -> unchanged
    """
    ts_str = ts_str.strip()
    parts = ts_str.split(":")
    # MM:SS (2 parts)
    if len(parts) == 2:
        mm, ss = map(int, parts)
        if 0 <= mm < 60 and 0 <= ss < 60:
            return f"00:{mm:02d}:{ss:02d}"
    # HH:MM:SS (3 parts)
    if len(parts) == 3:
        hh, mm, ss = map(int, parts)
        # if ends in :00, assume it was really MM:SS stored as HH:MM:00
        if ss == 0:
            return f"00:{hh:02d}:{mm:02d}"
        # otherwise valid HH:MM:SS
        if hh >= 0 and 0 <= mm < 60 and 0 <= ss < 60:
            return f"{hh:02d}:{mm:02d}:{ss:02d}"
    raise ValueError(f"Invalid timestamp format: '{ts_str}'")

def ffmpeg_cut_segment(input_path, start_ts, end_ts, output_path):
    """
    Reliable cut: seek before input, fixed duration, always re-encode
    with a keyframe at start and proper header.
    """
    start_sec = timestamp_to_seconds(start_ts)
    end_sec   = timestamp_to_seconds(end_ts)
    duration  = end_sec - start_sec
    if duration <= 0:
        raise RuntimeError(f"Invalid segment length: {start_ts} → {end_ts}")

    cmd = [
        "ffmpeg",
        "-hide_banner",
        "-loglevel", "info",
        "-ss",            start_ts,        # seek before input
        "-i",             input_path,
        "-t",             str(duration),   # duration in seconds
        "-c:v",           "libx264",       # re-encode video
        "-preset",        "fast",
        "-crf",           "23",
        "-c:a",           "aac",           # re-encode audio
        "-movflags",      "+faststart",    # header at front
        "-pix_fmt",       "yuv420p",
        "-y",
        output_path
    ]

    print(f"→ Cutting '{input_path}' from {start_ts} for {duration}s → '{output_path}'")
    result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if result.returncode != 0:
        print(result.stderr)
        raise RuntimeError(f"ffmpeg failed with code {result.returncode}")

    size = os.path.getsize(output_path)
    if size < 2000:
        raise RuntimeError(f"Output file too small ({size} bytes)")
    print(f"✔ Created: {output_path} ({size:,} bytes)")

def split_videos_from_sheet(sheet_path, search_dir, output_dir):
    ensure_ffmpeg_exists()

    # read spreadsheet, forcing Start/End as strings
    converters = {
        "Start": lambda x: str(x).strip(),
        "End":   lambda x: str(x).strip()
    }
    if sheet_path.lower().endswith(".csv"):
        df = pd.read_csv(sheet_path, converters=converters)
    else:
        df = pd.read_excel(sheet_path, converters=converters)
    df.columns = df.columns.str.strip()

    required = {"Video Name", "Start", "End", "Label"}
    if not required.issubset(df.columns):
        raise ValueError(f"Missing columns: found {df.columns.tolist()}")

    os.makedirs(output_dir, exist_ok=True)
    success = 0

    for idx, row in df.iterrows():
        try:
            name = str(row["Video Name"]).strip()
            if not name or name.lower() in ("nan", "none"):
                continue
            raw_start = row["Start"]
            raw_end   = row["End"]
            label     = str(row["Label"]).strip().lower().replace(" ", "_")

            print(f"\n[DEBUG] Row {idx+1}: Raw Start='{raw_start}', End='{raw_end}'")
            start_ts = validate_timestamp(raw_start)
            end_ts   = validate_timestamp(raw_end)
            print(f"[DEBUG] Row {idx+1}: Normalized {start_ts} → {end_ts}")

            video_path = find_video(name, search_dir)
            if video_path is None:
                print(f"[!] Video not found for '{name}' (skipping)")
                continue

            label_dir = os.path.join(output_dir, label)
            os.makedirs(label_dir, exist_ok=True)
            out_file = os.path.join(label_dir, f"{name}_{idx+1:03}.mp4")

            ffmpeg_cut_segment(video_path, start_ts, end_ts, out_file)
            success += 1

        except Exception as e:
            print(f"[X] Row {idx+1} failed: {e}")

    total = len(df)
    print(f"\nDone: {success}/{total} segments created.")

if __name__ == "__main__":
    split_videos_from_sheet(
        sheet_path="time_stamps/Boxing_Videos_Timestamp.xlsx",
        search_dir=".",
        output_dir="dataset"
    )
# Out:
# [DEBUG] Row 1: Raw Start='00:29', End='00:31'
# [DEBUG] Row 1: Normalized 00:00:29 → 00:00:31
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:00:29 for 2s → 'dataset/jab/slow_motion_sparring_001.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_001.mp4 (338,861 bytes)
#
# [DEBUG] Row 2: Raw Start='00:32', End='00:35'
# [DEBUG] Row 2: Normalized 00:00:32 → 00:00:35
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:00:32 for 3s → 'dataset/right_hook/slow_motion_sparring_002.mp4'
# ✔ Created: dataset/right_hook/slow_motion_sparring_002.mp4 (724,735 bytes)
#
# [DEBUG] Row 3: Raw Start='01:58', End='02:00'
# [DEBUG] Row 3: Normalized 00:01:58 → 00:02:00
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:01:58 for 2s → 'dataset/jab/slow_motion_sparring_003.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_003.mp4 (484,031 bytes)
#
# [DEBUG] Row 4: Raw Start='02:00', End='02:03'
# [DEBUG] Row 4: Normalized 00:02:00 → 00:02:03
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:00 for 3s → 'dataset/jab/slow_motion_sparring_004.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_004.mp4 (725,719 bytes)
#
# [DEBUG] Row 5: Raw Start='02:04', End='02:06'
# [DEBUG] Row 5: Normalized 00:02:04 → 00:02:06
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:04 for 2s → 'dataset/idle/slow_motion_sparring_005.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_005.mp4 (390,103 bytes)
#
# [DEBUG] Row 6: Raw Start='02:08', End='02:10'
# [DEBUG] Row 6: Normalized 00:02:08 → 00:02:10
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:08 for 2s → 'dataset/jab/slow_motion_sparring_006.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_006.mp4 (425,139 bytes)
#
# [DEBUG] Row 7: Raw Start='02:10', End='02:13'
# [DEBUG] Row 7: Normalized 00:02:10 → 00:02:13
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:10 for 3s → 'dataset/cross/slow_motion_sparring_007.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_007.mp4 (804,328 bytes)
#
# [DEBUG] Row 8: Raw Start='02:13', End='02:15'
# [DEBUG] Row 8: Normalized 00:02:13 → 00:02:15
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:13 for 2s → 'dataset/idle/slow_motion_sparring_008.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_008.mp4 (386,742 bytes)
#
# [DEBUG] Row 9: Raw Start='02:15', End='02:17'
# [DEBUG] Row 9: Normalized 00:02:15 → 00:02:17
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:15 for 2s → 'dataset/block/slow_motion_sparring_009.mp4'
# ✔ Created: dataset/block/slow_motion_sparring_009.mp4 (351,092 bytes)
#
# [DEBUG] Row 10: Raw Start='02:18', End='02:20'
# [DEBUG] Row 10: Normalized 00:02:18 → 00:02:20
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:18 for 2s → 'dataset/jab/slow_motion_sparring_010.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_010.mp4 (416,104 bytes)
#
# [DEBUG] Row 11: Raw Start='02:20', End='02:22'
# [DEBUG] Row 11: Normalized 00:02:20 → 00:02:22
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:20 for 2s → 'dataset/cross/slow_motion_sparring_011.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_011.mp4 (502,520 bytes)
#
# [DEBUG] Row 12: Raw Start='02:23', End='02:25'
# [DEBUG] Row 12: Normalized 00:02:23 → 00:02:25
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:23 for 2s → 'dataset/jab/slow_motion_sparring_012.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_012.mp4 (432,989 bytes)
#
# [DEBUG] Row 13: Raw Start='02:25', End='02:28'
# [DEBUG] Row 13: Normalized 00:02:25 → 00:02:28
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:25 for 3s → 'dataset/jab/slow_motion_sparring_013.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_013.mp4 (692,805 bytes)
#
# [DEBUG] Row 14: Raw Start='02:29', End='02:32'
# [DEBUG] Row 14: Normalized 00:02:29 → 00:02:32
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:29 for 3s → 'dataset/idle/slow_motion_sparring_014.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_014.mp4 (493,892 bytes)
#
# [DEBUG] Row 15: Raw Start='02:34', End='02:38'
# [DEBUG] Row 15: Normalized 00:02:34 → 00:02:38
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:34 for 4s → 'dataset/cross/slow_motion_sparring_015.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_015.mp4 (830,094 bytes)
#
# [DEBUG] Row 16: Raw Start='02:38', End='02:41'
# [DEBUG] Row 16: Normalized 00:02:38 → 00:02:41
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:38 for 3s → 'dataset/left_uppercut/slow_motion_sparring_016.mp4'
# ✔ Created: dataset/left_uppercut/slow_motion_sparring_016.mp4 (794,289 bytes)
#
# [DEBUG] Row 17: Raw Start='02:43', End='02:45'
# [DEBUG] Row 17: Normalized 00:02:43 → 00:02:45
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:43 for 2s → 'dataset/idle/slow_motion_sparring_017.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_017.mp4 (336,294 bytes)
#
# [DEBUG] Row 18: Raw Start='02:47', End='02:49'
# [DEBUG] Row 18: Normalized 00:02:47 → 00:02:49
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:47 for 2s → 'dataset/jab/slow_motion_sparring_018.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_018.mp4 (447,820 bytes)
#
# [DEBUG] Row 19: Raw Start='02:49', End='02:52'
# [DEBUG] Row 19: Normalized 00:02:49 → 00:02:52
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:49 for 3s → 'dataset/right_hook/slow_motion_sparring_019.mp4'
# ✔ Created: dataset/right_hook/slow_motion_sparring_019.mp4 (872,906 bytes)
#
# [DEBUG] Row 20: Raw Start='02:52', End='02:55'
# [DEBUG] Row 20: Normalized 00:02:52 → 00:02:55
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:52 for 3s → 'dataset/left_hook/slow_motion_sparring_020.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_020.mp4 (886,265 bytes)
#
# [DEBUG] Row 21: Raw Start='02:57', End='03:00'
# [DEBUG] Row 21: Normalized 00:02:57 → 00:03:00
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:02:57 for 3s → 'dataset/idle/slow_motion_sparring_021.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_021.mp4 (546,273 bytes)
#
# [DEBUG] Row 22: Raw Start='03:00', End='03:04'
# [DEBUG] Row 22: Normalized 00:03:00 → 00:03:04
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:00 for 4s → 'dataset/jab/slow_motion_sparring_022.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_022.mp4 (896,650 bytes)
#
# [DEBUG] Row 23: Raw Start='03:04', End='03:06'
# [DEBUG] Row 23: Normalized 00:03:04 → 00:03:06
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:04 for 2s → 'dataset/jab/slow_motion_sparring_023.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_023.mp4 (444,230 bytes)
#
# [DEBUG] Row 24: Raw Start='03:06', End='03:09'
# [DEBUG] Row 24: Normalized 00:03:06 → 00:03:09
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:06 for 3s → 'dataset/cross/slow_motion_sparring_024.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_024.mp4 (790,285 bytes)
#
# [DEBUG] Row 25: Raw Start='03:09', End='03:12'
# [DEBUG] Row 25: Normalized 00:03:09 → 00:03:12
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:09 for 3s → 'dataset/left_hook/slow_motion_sparring_025.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_025.mp4 (848,497 bytes)
#
# [DEBUG] Row 26: Raw Start='03:15', End='03:17'
# [DEBUG] Row 26: Normalized 00:03:15 → 00:03:17
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:15 for 2s → 'dataset/idle/slow_motion_sparring_026.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_026.mp4 (357,402 bytes)
#
# [DEBUG] Row 27: Raw Start='03:18', End='03:20'
# [DEBUG] Row 27: Normalized 00:03:18 → 00:03:20
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:18 for 2s → 'dataset/cross/slow_motion_sparring_027.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_027.mp4 (377,507 bytes)
#
# [DEBUG] Row 28: Raw Start='03:20', End='03:23'
# [DEBUG] Row 28: Normalized 00:03:20 → 00:03:23
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:20 for 3s → 'dataset/left_hook/slow_motion_sparring_028.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_028.mp4 (817,743 bytes)
#
# [DEBUG] Row 29: Raw Start='03:25', End='03:28'
# [DEBUG] Row 29: Normalized 00:03:25 → 00:03:28
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:25 for 3s → 'dataset/idle/slow_motion_sparring_029.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_029.mp4 (680,801 bytes)
#
# [DEBUG] Row 30: Raw Start='03:29', End='03:31'
# [DEBUG] Row 30: Normalized 00:03:29 → 00:03:31
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:29 for 2s → 'dataset/jab/slow_motion_sparring_030.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_030.mp4 (438,806 bytes)
#
# [DEBUG] Row 31: Raw Start='03:32', End='03:34'
# [DEBUG] Row 31: Normalized 00:03:32 → 00:03:34
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:32 for 2s → 'dataset/right_uppercut/slow_motion_sparring_031.mp4'
# ✔ Created: dataset/right_uppercut/slow_motion_sparring_031.mp4 (463,331 bytes)
#
# [DEBUG] Row 32: Raw Start='03:34', End='03:36'
# [DEBUG] Row 32: Normalized 00:03:34 → 00:03:36
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:34 for 2s → 'dataset/left_hook/slow_motion_sparring_032.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_032.mp4 (499,976 bytes)
#
# [DEBUG] Row 33: Raw Start='03:38', End='03:42'
# [DEBUG] Row 33: Normalized 00:03:38 → 00:03:42
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:38 for 4s → 'dataset/idle/slow_motion_sparring_033.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_033.mp4 (690,831 bytes)
#
# [DEBUG] Row 34: Raw Start='03:44', End='03:47'
# [DEBUG] Row 34: Normalized 00:03:44 → 00:03:47
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:44 for 3s → 'dataset/jab/slow_motion_sparring_034.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_034.mp4 (620,770 bytes)
#
# [DEBUG] Row 35: Raw Start='03:48', End='03:50'
# [DEBUG] Row 35: Normalized 00:03:48 → 00:03:50
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:48 for 2s → 'dataset/jab/slow_motion_sparring_035.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_035.mp4 (419,871 bytes)
#
# [DEBUG] Row 36: Raw Start='03:50', End='03:52'
# [DEBUG] Row 36: Normalized 00:03:50 → 00:03:52
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:50 for 2s → 'dataset/cross/slow_motion_sparring_036.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_036.mp4 (474,639 bytes)
#
# [DEBUG] Row 37: Raw Start='03:52', End='03:54'
# [DEBUG] Row 37: Normalized 00:03:52 → 00:03:54
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:52 for 2s → 'dataset/left_hook/slow_motion_sparring_037.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_037.mp4 (542,146 bytes)
#
# [DEBUG] Row 38: Raw Start='03:57', End='04:00'
# [DEBUG] Row 38: Normalized 00:03:57 → 00:04:00
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:03:57 for 3s → 'dataset/idle/slow_motion_sparring_038.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_038.mp4 (530,985 bytes)
#
# [DEBUG] Row 39: Raw Start='04:02', End='04:04'
# [DEBUG] Row 39: Normalized 00:04:02 → 00:04:04
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:02 for 2s → 'dataset/jab/slow_motion_sparring_039.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_039.mp4 (473,674 bytes)
#
# [DEBUG] Row 40: Raw Start='04:04', End='04:06'
# [DEBUG] Row 40: Normalized 00:04:04 → 00:04:06
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:04 for 2s → 'dataset/cross/slow_motion_sparring_040.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_040.mp4 (516,440 bytes)
#
# [DEBUG] Row 41: Raw Start='04:07', End='04:09'
# [DEBUG] Row 41: Normalized 00:04:07 → 00:04:09
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:07 for 2s → 'dataset/left_uppercut/slow_motion_sparring_041.mp4'
# ✔ Created: dataset/left_uppercut/slow_motion_sparring_041.mp4 (495,839 bytes)
#
# [DEBUG] Row 42: Raw Start='04:11', End='04:13'
# [DEBUG] Row 42: Normalized 00:04:11 → 00:04:13
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:11 for 2s → 'dataset/idle/slow_motion_sparring_042.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_042.mp4 (389,481 bytes)
#
# [DEBUG] Row 43: Raw Start='04:15', End='04:17'
# [DEBUG] Row 43: Normalized 00:04:15 → 00:04:17
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:15 for 2s → 'dataset/jab/slow_motion_sparring_043.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_043.mp4 (489,888 bytes)
#
# [DEBUG] Row 44: Raw Start='04:17', End='04:20'
# [DEBUG] Row 44: Normalized 00:04:17 → 00:04:20
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:17 for 3s → 'dataset/left_hook/slow_motion_sparring_044.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_044.mp4 (824,176 bytes)
#
# [DEBUG] Row 45: Raw Start='04:20', End='04:22'
# [DEBUG] Row 45: Normalized 00:04:20 → 00:04:22
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:20 for 2s → 'dataset/cross/slow_motion_sparring_045.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_045.mp4 (544,838 bytes)
#
# [DEBUG] Row 46: Raw Start='04:23', End='04:25'
# [DEBUG] Row 46: Normalized 00:04:23 → 00:04:25
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:23 for 2s → 'dataset/left_hook/slow_motion_sparring_046.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_046.mp4 (584,938 bytes)
#
# [DEBUG] Row 47: Raw Start='04:27', End='04:29'
# [DEBUG] Row 47: Normalized 00:04:27 → 00:04:29
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:27 for 2s → 'dataset/idle/slow_motion_sparring_047.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_047.mp4 (416,489 bytes)
#
# [DEBUG] Row 48: Raw Start='04:30', End='04:33'
# [DEBUG] Row 48: Normalized 00:04:30 → 00:04:33
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:30 for 3s → 'dataset/jab/slow_motion_sparring_048.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_048.mp4 (567,958 bytes)
#
# [DEBUG] Row 49: Raw Start='04:34', End='04:36'
# [DEBUG] Row 49: Normalized 00:04:34 → 00:04:36
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:34 for 2s → 'dataset/left_hook/slow_motion_sparring_049.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_049.mp4 (468,864 bytes)
#
# [DEBUG] Row 50: Raw Start='04:37', End='04:38'
# [DEBUG] Row 50: Normalized 00:04:37 → 00:04:38
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:37 for 1s → 'dataset/cross/slow_motion_sparring_050.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_050.mp4 (245,257 bytes)
#
# [DEBUG] Row 51: Raw Start='04:39', End='04:42'
# [DEBUG] Row 51: Normalized 00:04:39 → 00:04:42
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:39 for 3s → 'dataset/idle/slow_motion_sparring_051.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_051.mp4 (585,626 bytes)
#
# [DEBUG] Row 52: Raw Start='04:44', End='04:48'
# [DEBUG] Row 52: Normalized 00:04:44 → 00:04:48
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:44 for 4s → 'dataset/right_uppercut/slow_motion_sparring_052.mp4'
# ✔ Created: dataset/right_uppercut/slow_motion_sparring_052.mp4 (741,626 bytes)
#
# [DEBUG] Row 53: Raw Start='04:49', End='04:51'
# [DEBUG] Row 53: Normalized 00:04:49 → 00:04:51
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:49 for 2s → 'dataset/left_hook/slow_motion_sparring_053.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_053.mp4 (494,373 bytes)
#
# [DEBUG] Row 54: Raw Start='04:53', End='04:56'
# [DEBUG] Row 54: Normalized 00:04:53 → 00:04:56
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:53 for 3s → 'dataset/idle/slow_motion_sparring_054.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_054.mp4 (597,184 bytes)
#
# [DEBUG] Row 55: Raw Start='04:58', End='05:00'
# [DEBUG] Row 55: Normalized 00:04:58 → 00:05:00
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:04:58 for 2s → 'dataset/jab/slow_motion_sparring_055.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_055.mp4 (516,528 bytes)
#
# [DEBUG] Row 56: Raw Start='05:01', End='05:03'
# [DEBUG] Row 56: Normalized 00:05:01 → 00:05:03
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:01 for 2s → 'dataset/left_uppercut/slow_motion_sparring_056.mp4'
# ✔ Created: dataset/left_uppercut/slow_motion_sparring_056.mp4 (476,524 bytes)
#
# [DEBUG] Row 57: Raw Start='05:04', End='05:06'
# [DEBUG] Row 57: Normalized 00:05:04 → 00:05:06
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:04 for 2s → 'dataset/cross/slow_motion_sparring_057.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_057.mp4 (540,987 bytes)
#
# [DEBUG] Row 58: Raw Start='05:06', End='05:08'
# [DEBUG] Row 58: Normalized 00:05:06 → 00:05:08
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:06 for 2s → 'dataset/left_uppercut/slow_motion_sparring_058.mp4'
# ✔ Created: dataset/left_uppercut/slow_motion_sparring_058.mp4 (549,534 bytes)
#
# [DEBUG] Row 59: Raw Start='05:10', End='05:13'
# [DEBUG] Row 59: Normalized 00:05:10 → 00:05:13
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:10 for 3s → 'dataset/idle/slow_motion_sparring_059.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_059.mp4 (554,447 bytes)
#
# [DEBUG] Row 60: Raw Start='05:15', End='05:17'
# [DEBUG] Row 60: Normalized 00:05:15 → 00:05:17
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:15 for 2s → 'dataset/jab/slow_motion_sparring_060.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_060.mp4 (494,427 bytes)
#
# [DEBUG] Row 61: Raw Start='05:17', End='05:19'
# [DEBUG] Row 61: Normalized 00:05:17 → 00:05:19
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:17 for 2s → 'dataset/cross/slow_motion_sparring_061.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_061.mp4 (432,776 bytes)
#
# [DEBUG] Row 62: Raw Start='05:20', End='05:22'
# [DEBUG] Row 62: Normalized 00:05:20 → 00:05:22
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:20 for 2s → 'dataset/cross/slow_motion_sparring_062.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_062.mp4 (371,673 bytes)
#
# [DEBUG] Row 63: Raw Start='05:23', End='05:26'
# [DEBUG] Row 63: Normalized 00:05:23 → 00:05:26
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:23 for 3s → 'dataset/idle/slow_motion_sparring_063.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_063.mp4 (535,042 bytes)
#
# [DEBUG] Row 64: Raw Start='05:28', End='05:29'
# [DEBUG] Row 64: Normalized 00:05:28 → 00:05:29
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:28 for 1s → 'dataset/jab/slow_motion_sparring_064.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_064.mp4 (239,251 bytes)
#
# [DEBUG] Row 65: Raw Start='05:29', End='05:31'
# [DEBUG] Row 65: Normalized 00:05:29 → 00:05:31
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:29 for 2s → 'dataset/cross/slow_motion_sparring_065.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_065.mp4 (382,154 bytes)
#
# [DEBUG] Row 66: Raw Start='05:32', End='05:34'
# [DEBUG] Row 66: Normalized 00:05:32 → 00:05:34
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:32 for 2s → 'dataset/left_hook/slow_motion_sparring_066.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_066.mp4 (501,221 bytes)
#
# [DEBUG] Row 67: Raw Start='05:37', End='05:39'
# [DEBUG] Row 67: Normalized 00:05:37 → 00:05:39
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:37 for 2s → 'dataset/idle/slow_motion_sparring_067.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_067.mp4 (340,001 bytes)
#
# [DEBUG] Row 68: Raw Start='05:41', End='05:43'
# [DEBUG] Row 68: Normalized 00:05:41 → 00:05:43
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:41 for 2s → 'dataset/jab/slow_motion_sparring_068.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_068.mp4 (350,160 bytes)
#
# [DEBUG] Row 69: Raw Start='05:44', End='05:46'
# [DEBUG] Row 69: Normalized 00:05:44 → 00:05:46
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:44 for 2s → 'dataset/right_hook/slow_motion_sparring_069.mp4'
# ✔ Created: dataset/right_hook/slow_motion_sparring_069.mp4 (504,569 bytes)
#
# [DEBUG] Row 70: Raw Start='05:53', End='05:55'
# [DEBUG] Row 70: Normalized 00:05:53 → 00:05:55
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:53 for 2s → 'dataset/left_hook/slow_motion_sparring_070.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_070.mp4 (509,308 bytes)
#
# [DEBUG] Row 71: Raw Start='05:58', End='06:01'
# [DEBUG] Row 71: Normalized 00:05:58 → 00:06:01
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:05:58 for 3s → 'dataset/idle/slow_motion_sparring_071.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_071.mp4 (590,655 bytes)
#
# [DEBUG] Row 72: Raw Start='06:04', End='06:08'
# [DEBUG] Row 72: Normalized 00:06:04 → 00:06:08
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:04 for 4s → 'dataset/left_hook/slow_motion_sparring_072.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_072.mp4 (805,555 bytes)
#
# [DEBUG] Row 73: Raw Start='06:11', End='06:13'
# [DEBUG] Row 73: Normalized 00:06:11 → 00:06:13
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:11 for 2s → 'dataset/idle/slow_motion_sparring_073.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_073.mp4 (382,491 bytes)
#
# [DEBUG] Row 74: Raw Start='06:16', End='06:18'
# [DEBUG] Row 74: Normalized 00:06:16 → 00:06:18
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:16 for 2s → 'dataset/right_uppercut/slow_motion_sparring_074.mp4'
# ✔ Created: dataset/right_uppercut/slow_motion_sparring_074.mp4 (419,666 bytes)
#
# [DEBUG] Row 75: Raw Start='06:18', End='06:20'
# [DEBUG] Row 75: Normalized 00:06:18 → 00:06:20
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:18 for 2s → 'dataset/left_hook/slow_motion_sparring_075.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_075.mp4 (476,103 bytes)
#
# [DEBUG] Row 76: Raw Start='06:21', End='06:23'
# [DEBUG] Row 76: Normalized 00:06:21 → 00:06:23
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:21 for 2s → 'dataset/cross/slow_motion_sparring_076.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_076.mp4 (457,503 bytes)
#
# [DEBUG] Row 77: Raw Start='06:24', End='06:26'
# [DEBUG] Row 77: Normalized 00:06:24 → 00:06:26
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:24 for 2s → 'dataset/left_uppercut/slow_motion_sparring_077.mp4'
# ✔ Created: dataset/left_uppercut/slow_motion_sparring_077.mp4 (473,709 bytes)
#
# [DEBUG] Row 78: Raw Start='06:32', End='06:34'
# [DEBUG] Row 78: Normalized 00:06:32 → 00:06:34
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:32 for 2s → 'dataset/jab/slow_motion_sparring_078.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_078.mp4 (443,137 bytes)
#
# [DEBUG] Row 79: Raw Start='06:34', End='06:36'
# [DEBUG] Row 79: Normalized 00:06:34 → 00:06:36
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:34 for 2s → 'dataset/cross/slow_motion_sparring_079.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_079.mp4 (510,165 bytes)
#
# [DEBUG] Row 80: Raw Start='06:36', End='06:38'
# [DEBUG] Row 80: Normalized 00:06:36 → 00:06:38
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:36 for 2s → 'dataset/left_hook/slow_motion_sparring_080.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_080.mp4 (537,293 bytes)
#
# [DEBUG] Row 81: Raw Start='06:39', End='06:42'
# [DEBUG] Row 81: Normalized 00:06:39 → 00:06:42
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:39 for 3s → 'dataset/jab/slow_motion_sparring_081.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_081.mp4 (767,782 bytes)
#
# [DEBUG] Row 82: Raw Start='06:43', End='06:45'
# [DEBUG] Row 82: Normalized 00:06:43 → 00:06:45
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:43 for 2s → 'dataset/idle/slow_motion_sparring_082.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_082.mp4 (402,376 bytes)
#
# [DEBUG] Row 83: Raw Start='06:46', End='06:48'
# [DEBUG] Row 83: Normalized 00:06:46 → 00:06:48
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:46 for 2s → 'dataset/jab/slow_motion_sparring_083.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_083.mp4 (465,486 bytes)
#
# [DEBUG] Row 84: Raw Start='06:49', End='06:51'
# [DEBUG] Row 84: Normalized 00:06:49 → 00:06:51
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:49 for 2s → 'dataset/left_hook/slow_motion_sparring_084.mp4'
# ✔ Created: dataset/left_hook/slow_motion_sparring_084.mp4 (491,983 bytes)
#
# [DEBUG] Row 85: Raw Start='06:53', End='06:55'
# [DEBUG] Row 85: Normalized 00:06:53 → 00:06:55
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:53 for 2s → 'dataset/jab/slow_motion_sparring_085.mp4'
# ✔ Created: dataset/jab/slow_motion_sparring_085.mp4 (541,022 bytes)
#
# [DEBUG] Row 86: Raw Start='06:56', End='06:58'
# [DEBUG] Row 86: Normalized 00:06:56 → 00:06:58
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:06:56 for 2s → 'dataset/idle/slow_motion_sparring_086.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_086.mp4 (392,695 bytes)
#
# [DEBUG] Row 87: Raw Start='07:00', End='07:02'
# [DEBUG] Row 87: Normalized 00:07:00 → 00:07:02
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:07:00 for 2s → 'dataset/cross/slow_motion_sparring_087.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_087.mp4 (442,770 bytes)
#
# [DEBUG] Row 88: Raw Start='07:04', End='07:07'
# [DEBUG] Row 88: Normalized 00:07:04 → 00:07:07
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:07:04 for 3s → 'dataset/cross/slow_motion_sparring_088.mp4'
# ✔ Created: dataset/cross/slow_motion_sparring_088.mp4 (607,524 bytes)
#
# [DEBUG] Row 89: Raw Start='07:10', End='07:15'
# [DEBUG] Row 89: Normalized 00:07:10 → 00:07:15
# → Cutting './data_raw/sparring_pov/slow_motion_sparring.mp4' from 00:07:10 for 5s → 'dataset/idle/slow_motion_sparring_089.mp4'
# ✔ Created: dataset/idle/slow_motion_sparring_089.mp4 (850,606 bytes)
#
# Done: 89/89 segments created.

# %% [markdown]
# ### Dataset with poses

# %%
import os
import cv2
import imageio
import numpy as np
import pandas as pd
from ultralytics import YOLO

# ─────────────────────────────────────────────────────────────────────────────
# CONFIGURATION (edit as needed)
# ─────────────────────────────────────────────────────────────────────────────
POSE_MODEL_PATH = "models/yolo11n-pose.pt"   # path to your YOLO-pose .pt file
VIDEO_ROOT      = "dataset"                 # root folder containing subfolders of .mp4 videos
OUTPUT_ROOT     = "dataset_with_poses"      # root where .npy and labels.csv will be saved

# ─────────────────────────────────────────────────────────────────────────────
# Utility Functions
# ─────────────────────────────────────────────────────────────────────────────

def read_frames(path):
    """Read all RGB frames from a video via imageio or OpenCV."""
    try:
        reader = imageio.get_reader(path, "ffmpeg")
        frames = [f for f in reader]
        reader.close()
        if frames:
            return frames
    except Exception:
        pass
    cap = cv2.VideoCapture(path)
    if not cap.isOpened():
        raise RuntimeError(f"Cannot open video: {path}")
    frames = []
    while True:
        ret, frame_bgr = cap.read()
        if not ret:
            break
        frames.append(cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB))
    cap.release()
    if not frames:
        raise RuntimeError(f"No frames read from: {path}")
    return frames


def extract_pose_sequence(model, video_path):
    """
    Run pose model on each frame. Returns numpy array shape (num_frames, 2*num_keypoints).
    """
    frames = read_frames(video_path)
    if not frames:
        return None

    # Infer number of keypoints by running on first frame with a detection
    num_kpts = None
    for frame in frames:
        results = model(frame)
        if results and results[0].keypoints is not None:
            kps = results[0].keypoints.xy.cpu().numpy()
            if kps.size:
                num_kpts = kps.shape[1]
                break
    if num_kpts is None:
        raise RuntimeError("No keypoints found; cannot infer count.")

    seq = []
    for frame in frames:
        results = model(frame)
        if results and results[0].keypoints is not None:
            kps = results[0].keypoints.xy.cpu().numpy()
            if kps.size > 0:
                coords = kps[0, :, :2].flatten()
            else:
                coords = np.zeros(num_kpts * 2, dtype=float)
        else:
            coords = np.zeros(num_kpts * 2, dtype=float)
        seq.append(coords)

    return np.stack(seq, axis=0)

# ─────────────────────────────────────────────────────────────────────────────
# Main Extraction: Walk nested folders
# ─────────────────────────────────────────────────────────────────────────────

model = YOLO(POSE_MODEL_PATH)
records = []
os.makedirs(OUTPUT_ROOT, exist_ok=True)

for dirpath, _, files in os.walk(VIDEO_ROOT):
    # skip root itself if videos not directly under
    for fname in files:
        if not fname.lower().endswith('.mp4'):
            continue
        video_path = os.path.join(dirpath, fname)
        # derive label from immediate subfolder under VIDEO_ROOT
        rel_path = os.path.relpath(dirpath, VIDEO_ROOT)
        label = os.path.normpath(rel_path).replace(os.sep, '_')
        clip = os.path.splitext(fname)[0]
        print(f"Processing [{label}] {clip}.mp4")
        try:
            seq = extract_pose_sequence(model, video_path)
        except Exception as e:
            print(f"  ↳ error extracting poses: {e}")
            continue
        if seq is None or seq.size == 0:
            print("  ↳ no pose data: skipping")
            continue

        # save .npy preserving label folder
        out_dir = os.path.join(OUTPUT_ROOT, label)
        os.makedirs(out_dir, exist_ok=True)
        npy_path = os.path.join(out_dir, f"{clip}.npy")
        np.save(npy_path, seq)
        records.append({'npy_path': npy_path, 'label': label})
        print(f"  ↳ saved {npy_path} (shape={seq.shape})")

# Write labels.csv at root
if records:
    df = pd.DataFrame(records)
    csv_file = os.path.join(OUTPUT_ROOT, 'labels.csv')
    df.to_csv(csv_file, index=False)
    print(f"labels.csv written to {csv_file}")
else:
    print("No pose data extracted; check your folder structure and model.")
# Out:
# Processing [block] slow_motion_sparring_009.mp4
#
# 0: 384x640 1 person, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.0ms
# Speed: 1.6ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.9ms
# Speed: 1.4ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.7ms
# Speed: 1.4ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.1ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.1ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.1ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.0ms
# Speed: 1.2ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/block/slow_motion_sparring_009.npy (shape=(60, 34))
# Processing [block] slow_motion_sparring_010.mp4
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.1ms
# Speed: 1.2ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.6ms
# Speed: 1.2ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.9ms
# Speed: 1.3ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.2ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/block/slow_motion_sparring_010.npy (shape=(60, 34))
# Processing [right_hook] slow_motion_sparring_069.mp4
#
# 0: 384x640 1 person, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.9ms
# Speed: 1.1ms preprocess, 6.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.4ms
# Speed: 1.1ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/right_hook/slow_motion_sparring_069.npy (shape=(60, 34))
# Processing [right_hook] slow_motion_sparring_002.mp4
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 19.4ms
# Speed: 1.9ms preprocess, 19.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.8ms
# Speed: 1.3ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.9ms
# Speed: 0.9ms preprocess, 6.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.5ms
# Speed: 1.3ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.9ms
# Speed: 1.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.8ms
# Speed: 1.2ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.4ms
# Speed: 1.5ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/right_hook/slow_motion_sparring_002.npy (shape=(90, 34))
# Processing [right_hook] slow_motion_sparring_019.mp4
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.8ms
# Speed: 2.3ms preprocess, 7.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.2ms
# Speed: 1.2ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.5ms
# Speed: 1.3ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/right_hook/slow_motion_sparring_019.npy (shape=(90, 34))
# Processing [right_hook] slow_motion_sparring_020.mp4
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# ...
#
# 0: 384x640 1 person, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.3ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.6ms
# Speed: 1.3ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/jab/slow_motion_sparring_003.npy (shape=(60, 34))
# Processing [jab] slow_motion_sparring_011.mp4
#
# 0: 384x640 1 person, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.3ms
# Speed: 1.4ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.3ms
# Speed: 1.4ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16.4ms
# Speed: 1.3ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.9ms
# Speed: 1.8ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.3ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.8ms
# Speed: 1.3ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.9ms
# Speed: 1.3ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#   ↳ saved dataset_with_poses/jab/slow_motion_sparring_011.npy (shape=(60, 34))
# Processing [jab] slow_motion_sparring_068.mp4
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.4ms
# Speed: 0.9ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.3ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11.7ms
# Speed: 1.1ms preprocess, 11.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### Visualize pose estimation on Video

# %%
# Batch Overlay from Numpy Pose Data (Notebook-Friendly)

import os
import cv2
import numpy as np
from IPython.display import Video, display

# ─────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ─────────────────────────────────────────────────────────────────────────────
VIDEO_ROOT   = "dataset"                        # root folder with label subfolders of .mp4
NPY_ROOT     = "dataset_with_poses"            # root folder with label subfolders of .npy
OUTPUT_ROOT  = "dataset_with_poses_visualization"  # where to save annotated videos
POINT_RADIUS = 4
LINE_THICK   = 2

# COCO skeleton connections (0-indexed keypoints)
SKELETON = [
    (0, 1), (0, 2), (1, 3), (2, 4),  # head
    (0, 5), (0, 6),                    # shoulders
    (5, 7), (7, 9),                    # left arm
    (6, 8), (8, 10),                   # right arm
    (5, 6),                            # across shoulders
    (5, 11), (6, 12),                  # torso sides
    (11, 12),                          # across hips
    (11, 13), (13, 15),                # left leg
    (12, 14), (14, 16)                 # right leg
]

# ─────────────────────────────────────────────────────────────────────────────
# Helper: Annotate one video given its pose array
# ─────────────────────────────────────────────────────────────────────────────
def annotate_video(video_path, poses, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Cannot open video: {video_path}")
    fps = cap.get(cv2.CAP_PROP_FPS) or 30
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(output_path, fourcc, fps, (w, h))
    num_frames = poses.shape[0]
    num_kpts = poses.shape[1] // 2

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_idx < num_frames:
            coords = poses[frame_idx].reshape(num_kpts, 2)
            # draw skeleton
            for i, j in SKELETON:
                x1, y1 = coords[i]
                x2, y2 = coords[j]
                if x1>0 and y1>0 and x2>0 and y2>0 and x1<w and y1<h and x2<w and y2<h:
                    cv2.line(frame, (int(x1),int(y1)), (int(x2),int(y2)), (0,255,0), LINE_THICK)
            # draw points
            for x, y in coords:
                if x>0 and y>0 and x<w and y<h:
                    cv2.circle(frame, (int(x),int(y)), POINT_RADIUS, (0,0,255), -1)
        writer.write(frame)
        frame_idx += 1
    cap.release()
    writer.release()
    return output_path

# ─────────────────────────────────────────────────────────────────────────────
# Batch Processing: Iterate over labels and videos
# ─────────────────────────────────────────────────────────────────────────────
os.makedirs(OUTPUT_ROOT, exist_ok=True)

for label in os.listdir(VIDEO_ROOT):
    vdir = os.path.join(VIDEO_ROOT, label)
    ndir = os.path.join(NPY_ROOT, label)
    odir = os.path.join(OUTPUT_ROOT, label)
    if not os.path.isdir(vdir) or not os.path.isdir(ndir):
        continue
    os.makedirs(odir, exist_ok=True)
    for fname in os.listdir(vdir):
        if not fname.lower().endswith('.mp4'):
            continue
        clip = os.path.splitext(fname)[0]
        video_path = os.path.join(vdir, fname)
        npy_path = os.path.join(ndir, f"{clip}.npy")
        if not os.path.exists(npy_path):
            print(f"No pose data for {clip}, skipping")
            continue
        poses = np.load(npy_path)
        out_video = os.path.join(odir, f"{clip}_annotated.mp4")
        print(f"Annotating {label}/{clip}.mp4 → {out_video}")
        annotate_video(video_path, poses, out_video)

# ─────────────────────────────────────────────────────────────────────────────
# Display one sample annotated video
# ─────────────────────────────────────────────────────────────────────────────
# Find first annotated file
for root, _, files in os.walk(OUTPUT_ROOT):
    for f in files:
        if f.lower().endswith('_annotated.mp4'):
            display(Video(os.path.join(root, f), embed=True, width=600))
            raise SystemExit

print("Batch annotation complete. Check", OUTPUT_ROOT)
# Out:
# Annotating block/slow_motion_sparring_009.mp4 → dataset_with_poses_visualization/block/slow_motion_sparring_009_annotated.mp4
# Annotating block/slow_motion_sparring_010.mp4 → dataset_with_poses_visualization/block/slow_motion_sparring_010_annotated.mp4
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3465: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
